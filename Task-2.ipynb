# %% [markdown]
# ## Pandas
#                                                                                                                 16|04|2024

# %%
# import pandas lib
import pandas as pd

# %%
# loading csv file
df=pd.read_csv("ds_salaries.csv")
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
# first five rows or tuples
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
# last five tuples
df.tail()
# Out:
#      Unnamed: 0  work_year experience_level employment_type      job_title  \
# 602         602       2022               SE              FT  Data Engineer
# 603         603       2022               SE              FT  Data Engineer
# 604         604       2022               SE              FT   Data Analyst
# 605         605       2022               SE              FT   Data Analyst
# 606         606       2022               MI              FT   AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# ...

# %%
# no. of rows and columns
df.shape
# Out:
# (607, 12)

# %%
# attributes
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
# renameing the attribute
df=df.rename(columns={"Unnamed: 0":"id"})

# %%
df
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
# ..   ...        ...              ...             ...
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
# 606  606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %%
# decribing the dataset
df.describe()
# Out:
#                id    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
# information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
# checking if any null values
df.isna().sum()
# Out:
# id                    0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# datatypes of attributes
df.dtypes
# Out:
# id                     int64
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
# salary column
df["salary"]
# Out:
# 0       70000
# 1      260000
# 2       85000
# 3       20000
# 4      150000
#         ...
# 602    154000
# 603    126000
# 604    129000
# 605    150000
# 606    200000
# Name: salary, Length: 607, dtype: int64

# %%
# unique values in salary
df["salary"].unique()
# Out:
# array([   70000,   260000,    85000,    20000,   150000,    72000,
#          190000, 11000000,   135000,   125000,    45000,  3000000,
#           35000,    87000,     8000,  4450000,   100000,   423000,
#           56000,   299000,   450000,    42000,    98000,   115000,
#          325000,   720000,   157000,    51999,    60000,    41000,
#           65000,   103000,   250000,    10000,   138000,    45760,
#           44000,   106000,    88000,    14000,   188000,   105000,
#           61500,    91000,   300000,    48000,   130000,    34000,
#          118000,   120000,   138350,   110000,   130800,    19000,
#          412000,    40000,    55000,    43200,   190200,    80000,
#           37000,   235000,   400000,   270000,    67000,   140000,
#           68000,    50000,   170000,    75000,  1450000,   276000,
#         2200000,    12000,    81000,    62000,    73000,    37456,
#         2250000,    82500,    38400,   225000,    90000,   200000,
# ...

# %%
# sum of salaries
df["salary"].sum()
# Out:
# 196668038

# %%
# minimum salary
df["salary"].min()
# Out:
# 4000

# %%
# maximum salary
df["salary"].max()
# Out:
# 30400000

# %%
# no.of salary accounts
df["salary"].count()
# Out:
# 607

# %%
# slicing the dataset
df[0:3]
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 0   0       2020               MI              FT              Data Scientist
# 1   1       2020               SE              FT  Machine Learning Scientist
# 2   2       2020               SE              FT           Big Data Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M

# %%
df.loc[0:3]
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 0   0       2020               MI              FT              Data Scientist
# 1   1       2020               SE              FT  Machine Learning Scientist
# 2   2       2020               SE              FT           Big Data Engineer
# 3   3       2020               MI              FT        Product Data Analyst
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S

# %%
df.iloc[0:3]
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 0   0       2020               MI              FT              Data Scientist
# 1   1       2020               SE              FT  Machine Learning Scientist
# 2   2       2020               SE              FT           Big Data Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M

# %%
# transpose
df.T
# Out:
#                                0                           1    \
# id                               0                           1
# work_year                     2020                        2020
# experience_level                MI                          SE
# employment_type                 FT                          FT
# job_title           Data Scientist  Machine Learning Scientist
# salary                       70000                      260000
# salary_currency                EUR                         USD
# salary_in_usd                79833                      260000
# employee_residence              DE                          JP
# remote_ratio                     0                           0
# company_location                DE                          JP
# company_size                     L                           S
#
#                                   2                     3    \
# id                                  2                     3
# ...

# %%
df
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
# ..   ...        ...              ...             ...
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
# 606  606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %%
# salaries morethan 155000
(df["salary"]<155000)
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 602     True
# 603     True
# 604     True
# 605     True
# 606    False
# Name: salary, Length: 607, dtype: bool

# %%
# checking if any duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
# droping if any duplicate values
df.drop_duplicates()
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
# ..   ...        ...              ...             ...
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
# 606  606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %%
# droping null values
df.dropna()
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
# ..   ...        ...              ...             ...
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
# 606  606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %%
# filling null values
df.fillna(value=0)
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
# ..   ...        ...              ...             ...
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
# 606  606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %%
pd.isnull(df)
# Out:
#         id  work_year  experience_level  employment_type  job_title  salary  \
# 0    False      False             False            False      False   False
# 1    False      False             False            False      False   False
# 2    False      False             False            False      False   False
# 3    False      False             False            False      False   False
# 4    False      False             False            False      False   False
# ..     ...        ...               ...              ...        ...     ...
# 602  False      False             False            False      False   False
# 603  False      False             False            False      False   False
# 604  False      False             False            False      False   False
# 605  False      False             False            False      False   False
# 606  False      False             False            False      False   False
#
# ...

# %%
pd.isnull(df).sum().sum()
# Out:
# 0

# %%
# minimun values in each attribute
df.min()
# Out:
# id                                                0
# work_year                                      2020
# experience_level                                 EN
# employment_type                                  CT
# job_title             3D Computer Vision Researcher
# salary                                         4000
# salary_currency                                 AUD
# salary_in_usd                                  2859
# employee_residence                               AE
# remote_ratio                                      0
# company_location                                 AE
# company_size                                      L
# dtype: object

# %%
# cumulative sum of salary attribute
df["salary"].cumsum()
# Out:
# 0          70000
# 1         330000
# 2         415000
# 3         435000
# 4         585000
#          ...
# 602    196063038
# 603    196189038
# 604    196318038
# 605    196468038
# 606    196668038
# Name: salary, Length: 607, dtype: int64

# %%
df["salary"].sum()
# Out:
# 196668038

# %%
df.index
# Out:
# RangeIndex(start=0, stop=607, step=1)

# %%
# droping the attribute remote_ratio
df.drop("remote_ratio",axis=1,inplace=True)

# %%
df
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
# ..   ...        ...              ...             ...
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
# 606  606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %%
df.head(2)
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 0   0       2020               MI              FT              Data Scientist
# 1   1       2020               SE              FT  Machine Learning Scientist
#
#    salary salary_currency  salary_in_usd employee_residence company_location  \
# 0   70000             EUR          79833                 DE               DE
# 1  260000             USD         260000                 JP               JP
#
#   company_size
# 0            L
# 1            S

# %%
# unique values in employee_residence
df["employee_residence"].unique()
# Out:
# array(['DE', 'JP', 'GB', 'HN', 'US', 'HU', 'NZ', 'FR', 'IN', 'PK', 'PL',
#        'PT', 'CN', 'GR', 'AE', 'NL', 'MX', 'CA', 'AT', 'NG', 'PH', 'ES',
#        'DK', 'RU', 'IT', 'HR', 'BG', 'SG', 'BR', 'IQ', 'VN', 'BE', 'UA',
#        'MT', 'CL', 'RO', 'IR', 'CO', 'MD', 'KE', 'SI', 'HK', 'TR', 'RS',
#        'PR', 'LU', 'JE', 'CZ', 'AR', 'DZ', 'TN', 'MY', 'EE', 'AU', 'BO',
#        'IE', 'CH'], dtype=object)

# %%
# Data Scientist roes in the dataset
df[df['job_title'].str.contains('Data Scientist')]
# Out:
#       id  work_year experience_level employment_type            job_title  \
# 0      0       2020               MI              FT       Data Scientist
# 6      6       2020               SE              FT  Lead Data Scientist
# 7      7       2020               MI              FT       Data Scientist
# 10    10       2020               EN              FT       Data Scientist
# 11    11       2020               MI              FT       Data Scientist
# ..   ...        ...              ...             ...                  ...
# 592  592       2022               SE              FT       Data Scientist
# 593  593       2022               SE              FT       Data Scientist
# 596  596       2022               SE              FT       Data Scientist
# 598  598       2022               MI              FT       Data Scientist
# 599  599       2022               MI              FT       Data Scientist
#
#        salary salary_currency  salary_in_usd employee_residence  \
# ...

# %%
# no.of data scientist rows
df[df["job_title"] == 'Data Scientist'].count()
# Out:
# id                    143
# work_year             143
# experience_level      143
# employment_type       143
# job_title             143
# salary                143
# salary_currency       143
# salary_in_usd         143
# employee_residence    143
# company_location      143
# company_size          143
# dtype: int64

# %%
# job title unique values
df["job_title"].unique()
# Out:
# array(['Data Scientist', 'Machine Learning Scientist',
#        'Big Data Engineer', 'Product Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst', 'Lead Data Scientist',
#        'Business Data Analyst', 'Lead Data Engineer', 'Lead Data Analyst',
#        'Data Engineer', 'Data Science Consultant', 'BI Data Analyst',
#        'Director of Data Science', 'Research Scientist',
#        'Machine Learning Manager', 'Data Engineering Manager',
#        'Machine Learning Infrastructure Engineer', 'ML Engineer',
#        'AI Scientist', 'Computer Vision Engineer',
#        'Principal Data Scientist', 'Data Science Manager', 'Head of Data',
#        '3D Computer Vision Researcher', 'Data Analytics Engineer',
#        'Applied Data Scientist', 'Marketing Data Analyst',
#        'Cloud Data Engineer', 'Financial Data Analyst',
#        'Computer Vision Software Engineer',
#        'Director of Data Engineering', 'Data Science Engineer',
# ...

# %%
df["job_title"].count()
# Out:
# 607

# %%
df
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
# ..   ...        ...              ...             ...
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
# 606  606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %%
df[df["job_title"].isin(['Big Data Engineer', 'Data Scientist', 'Machine Learning Scientist', 'Product Data Analyst', 'Machine Learning Engineer'])].count()
# Out:
# id                    202
# work_year             202
# experience_level      202
# employment_type       202
# job_title             202
# salary                202
# salary_currency       202
# salary_in_usd         202
# employee_residence    202
# company_location      202
# company_size          202
# dtype: int64

# %%
df
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
# ..   ...        ...              ...             ...
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
# 606  606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %%
# first five rows of data scientist which is having morethan 150000 salary 
df[(df["salary"]>150000) & (df["job_title"] == 'Data Scientist')].head(5)
# Out:
#       id  work_year experience_level employment_type       job_title  \
# 7      7       2020               MI              FT  Data Scientist
# 11    11       2020               MI              FT  Data Scientist
# 63    63       2020               SE              FT  Data Scientist
# 94    94       2021               EN              FT  Data Scientist
# 127  127       2021               MI              FT  Data Scientist
#
#        salary salary_currency  salary_in_usd employee_residence  \
# 7    11000000             HUF          35735                 HU
# 11    3000000             INR          40481                 IN
# 63     412000             USD         412000                 US
# 94    2200000             INR          29751                 IN
# 127    700000             INR           9466                 IN
#
#     company_location company_size
# 7                 HU            L
# 11                IN            L
# 63                US            L
# ...

# %%
# last five rows of data scientist which is having morethan 150000 salary
df[(df["salary"]>150000) & (df["job_title"] == 'Data Scientist')].tail()
# Out:
#       id  work_year experience_level employment_type       job_title  salary  \
# 574  574       2022               SE              FT  Data Scientist  210000
# 576  576       2022               SE              FT  Data Scientist  210000
# 592  592       2022               SE              FT  Data Scientist  230000
# 596  596       2022               SE              FT  Data Scientist  210000
# 598  598       2022               MI              FT  Data Scientist  160000
#
#     salary_currency  salary_in_usd employee_residence company_location  \
# 574             USD         210000                 US               US
# 576             USD         210000                 US               US
# 592             USD         230000                 US               US
# 596             USD         210000                 US               US
# 598             USD         160000                 US               US
#
#     company_size
# 574            M
# 576            M
# 592            M
# ...

# %%
option = ["US","JP"]

# %%
# company location at US and JP 
df[df["company_location"].isin(option)]
# Out:
#       id  work_year experience_level employment_type  \
# 1      1       2020               SE              FT
# 4      4       2020               SE              FT
# 5      5       2020               EN              FT
# 6      6       2020               SE              FT
# 8      8       2020               MI              FT
# ..   ...        ...              ...             ...
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
# 606  606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 1    Machine Learning Scientist  260000             USD         260000
# 4     Machine Learning Engineer  150000             USD         150000
# 5                  Data Analyst   72000             USD          72000
# ...
